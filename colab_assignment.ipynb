# %% [markdown]
# Colab Link: https://colab.research.google.com/drive/1gRMKBHstLIWrFAAul0OznNRzXMkqXWX6?usp=sharing

# %%
print("Hello, this is my Colab assignment")
# Out:
# Hello, this is my Colab assignment
